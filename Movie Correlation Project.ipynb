# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %%
df = pd.read_csv(r'C:\Users\clemo\Downloads\movies1.csv')

# %%
df.head()
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 5419                               Bad Boys for Life          R     Action
# 5420                              Sonic the Hedgehog         PG     Action
# 5421                                        Dolittle         PG  Adventure
# 5422                            The Call of the Wild         PG  Adventure
# 5423                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score    votes  \
# 0     1980      June 13, 1980 (United States)    8.4   927000
# 1     1980       July 2, 1980 (United States)    5.8    65000
# 2     1980      June 20, 1980 (United States)    8.7  1200000
# 3     1980       July 2, 1980 (United States)    7.7   221000
# 4     1980      July 25, 1980 (United States)    7.3   108000
# ...    ...                                ...    ...      ...
# 5419  2020   January 17, 2020 (United States)    6.6   140000
# 5420  2020  February 14, 2020 (United States)    6.5   102000
# 5421  2020   January 17, 2020 (United States)    5.6    53000
# 5422  2020  February 21, 2020 (United States)    6.8    42000
# 5423  2020    August 28, 2020 (United States)    6.8     3700
#
#              director                   writer               star  \
# 0     Stanley Kubrick             Stephen King     Jack Nicholson
# 1      Randal Kleiser  Henry De Vere Stacpoole     Brooke Shields
# 2      Irvin Kershner           Leigh Brackett        Mark Hamill
# 3        Jim Abrahams             Jim Abrahams        Robert Hays
# 4        Harold Ramis       Brian Doyle-Murray        Chevy Chase
# ...               ...                      ...                ...
# 5419     Adil El Arbi              Peter Craig         Will Smith
# 5420      Jeff Fowler                Pat Casey       Ben Schwartz
# 5421   Stephen Gaghan           Stephen Gaghan  Robert Downey Jr.
# 5422    Chris Sanders            Michael Green      Harrison Ford
# 5423          Hu Guan                  Hu Guan    Zhi-zhong Huang
#
#              country     budget      gross  \
# 0     United Kingdom   19000000   46998772
# 1      United States    4500000   58853106
# 2      United States   18000000  538375067
# 3      United States    3500000   83453539
# 4      United States    6000000   39846344
# ...              ...        ...        ...
# 5419   United States   90000000  426505244
# 5420   United States   85000000  319715683
# 5421   United States  175000000  245487753
# 5422          Canada  135000000  111105497
# 5423           China   80000000  461421559
#
#                                   company  runtime
# 0                            Warner Bros.    146.0
# 1                       Columbia Pictures    104.0
# 2                               Lucasfilm    124.0
# 3                      Paramount Pictures     88.0
# 4                          Orion Pictures     98.0
# ...                                   ...      ...
# 5419                    Columbia Pictures    124.0
# 5420                   Paramount Pictures     99.0
# 5421                   Universal Pictures    101.0
# 5422                 20th Century Studios    100.0
# 5423  Beijing Diqi Yinxiang Entertainment    149.0
#
# [5424 rows x 15 columns]

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 0%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 0%
# gross - 0%
# company - 0%
# runtime - 0%

# %%
print(df.dtypes)
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes         int64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
df.boxplot(column=['gross'])
# Out:
# <AxesSubplot:>

# %%
df.drop_duplicates()
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 5419                               Bad Boys for Life          R     Action
# 5420                              Sonic the Hedgehog         PG     Action
# 5421                                        Dolittle         PG  Adventure
# 5422                            The Call of the Wild         PG  Adventure
# 5423                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score    votes  \
# 0     1980      June 13, 1980 (United States)    8.4   927000
# 1     1980       July 2, 1980 (United States)    5.8    65000
# 2     1980      June 20, 1980 (United States)    8.7  1200000
# 3     1980       July 2, 1980 (United States)    7.7   221000
# 4     1980      July 25, 1980 (United States)    7.3   108000
# ...    ...                                ...    ...      ...
# 5419  2020   January 17, 2020 (United States)    6.6   140000
# 5420  2020  February 14, 2020 (United States)    6.5   102000
# 5421  2020   January 17, 2020 (United States)    5.6    53000
# 5422  2020  February 21, 2020 (United States)    6.8    42000
# 5423  2020    August 28, 2020 (United States)    6.8     3700
#
#              director                   writer               star  \
# 0     Stanley Kubrick             Stephen King     Jack Nicholson
# 1      Randal Kleiser  Henry De Vere Stacpoole     Brooke Shields
# 2      Irvin Kershner           Leigh Brackett        Mark Hamill
# 3        Jim Abrahams             Jim Abrahams        Robert Hays
# 4        Harold Ramis       Brian Doyle-Murray        Chevy Chase
# ...               ...                      ...                ...
# 5419     Adil El Arbi              Peter Craig         Will Smith
# 5420      Jeff Fowler                Pat Casey       Ben Schwartz
# 5421   Stephen Gaghan           Stephen Gaghan  Robert Downey Jr.
# 5422    Chris Sanders            Michael Green      Harrison Ford
# 5423          Hu Guan                  Hu Guan    Zhi-zhong Huang
#
#              country     budget      gross  \
# 0     United Kingdom   19000000   46998772
# 1      United States    4500000   58853106
# 2      United States   18000000  538375067
# 3      United States    3500000   83453539
# 4      United States    6000000   39846344
# ...              ...        ...        ...
# 5419   United States   90000000  426505244
# 5420   United States   85000000  319715683
# 5421   United States  175000000  245487753
# 5422          Canada  135000000  111105497
# 5423           China   80000000  461421559
#
#                                   company  runtime
# 0                            Warner Bros.    146.0
# 1                       Columbia Pictures    104.0
# 2                               Lucasfilm    124.0
# 3                      Paramount Pictures     88.0
# 4                          Orion Pictures     98.0
# ...                                   ...      ...
# 5419                    Columbia Pictures    124.0
# 5420                   Paramount Pictures     99.0
# 5421                   Universal Pictures    101.0
# 5422                 20th Century Studios    100.0
# 5423  Beijing Diqi Yinxiang Entertainment    149.0
#
# [5424 rows x 15 columns]

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name     rating   genre  year  \
# 3733                                      Avatar      PG-13  Action  2009
# 5305                           Avengers: Endgame      PG-13  Action  2019
# 1797                                     Titanic      PG-13   Drama  1997
# 4733  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 5161                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 3900                                 Tanner Hall          R   Drama  2009
# 1380                  Philadelphia Experiment II      PG-13  Action  1993
# 2288                                Ginger Snaps  Not Rated   Drama  2000
# 154                                     Parasite          R  Horror  1982
# 1922                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score    votes             director  \
# 3733  December 18, 2009 (United States)    7.8  1100000        James Cameron
# 5305     April 26, 2019 (United States)    8.4   903000        Anthony Russo
# 1797  December 19, 1997 (United States)    7.8  1100000        James Cameron
# 4733  December 18, 2015 (United States)    7.8   876000          J.J. Abrams
# 5161     April 27, 2018 (United States)    8.4   897000        Anthony Russo
# ...                                 ...    ...      ...                  ...
# 3900          January 15, 2015 (Sweden)    5.8     3500  Francesca Gregorini
# 1380         June 4, 1994 (South Korea)    4.5     1900     Stephen Cornwell
# 2288              May 11, 2001 (Canada)    6.8    43000         John Fawcett
# 154      March 12, 1982 (United States)    3.9     2300         Charles Band
# 1922           October 1, 1997 (Brazil)    5.7     5800         George Huang
#
#                        writer               star        country     budget  \
# 3733            James Cameron    Sam Worthington  United States  237000000
# 5305       Christopher Markus  Robert Downey Jr.  United States  356000000
# 1797            James Cameron  Leonardo DiCaprio  United States  200000000
# 4733          Lawrence Kasdan       Daisy Ridley  United States  245000000
# 5161       Christopher Markus  Robert Downey Jr.  United States  321000000
# ...                       ...                ...            ...        ...
# 3900  Tatiana von Fürstenberg        Rooney Mara  United States    3000000
# 1380       Wallace C. Bennett       Brad Johnson  United States    5000000
# 2288             Karen Walton      Emily Perkins         Canada    5000000
# 154             Alan J. Adler    Robert Glaudini  United States     800000
# 1922                Andy Burg       Will Friedle  United States   15000000
#
#            gross                    company  runtime
# 3733  2847246203      Twentieth Century Fox    162.0
# 5305  2797501328             Marvel Studios    181.0
# 1797  2201647264      Twentieth Century Fox    194.0
# 4733  2069521700                  Lucasfilm    138.0
# 5161  2048359754             Marvel Studios    149.0
# ...          ...                        ...      ...
# 3900        5073           Two Prong Lesson     96.0
# 1380        2970           Trimark Pictures     97.0
# 2288        2554  Copperheart Entertainment    108.0
# 154         2270           Embassy Pictures     85.0
# 1922         309                   Daybreak     85.0
#
# [5424 rows x 15 columns]

# %%
sns.regplot(x="gross", y="budget", data=df)
# Out:
# <AxesSubplot:xlabel='gross', ylabel='budget'>

# %%
sns.regplot(x="score", y="gross", data=df)
# Out:
# <AxesSubplot:xlabel='score', ylabel='gross'>

# %%
df.corr(method ='pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056506  0.206161  0.327961  0.274395  0.075173
# score    0.056506  1.000000  0.474349  0.072155  0.222709  0.414145
# votes    0.206161  0.474349  1.000000  0.439757  0.614808  0.352331
# budget   0.327961  0.072155  0.439757  1.000000  0.740263  0.318718
# gross    0.274395  0.222709  0.614808  0.740263  1.000000  0.275830
# runtime  0.075173  0.414145  0.352331  0.318718  0.275830  1.000000

# %%
df.corr(method ='kendall')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.039508  0.296806  0.221252  0.239831  0.064846
# score    0.039508  1.000000  0.350307 -0.006222  0.125195  0.292308
# votes    0.296806  0.350307  1.000000  0.346585  0.553847  0.205299
# budget   0.221252 -0.006222  0.346585  1.000000  0.512191  0.231188
# gross    0.239831  0.125195  0.553847  0.512191  1.000000  0.176992
# runtime  0.064846  0.292308  0.205299  0.231188  0.176992  1.000000

# %%
df.corr(method ='spearman')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.057921  0.428012  0.313480  0.351464  0.095483
# score    0.057921  1.000000  0.495593 -0.009701  0.183567  0.412220
# votes    0.428012  0.495593  1.000000  0.493816  0.745999  0.300576
# budget   0.313480 -0.009701  0.493816  1.000000  0.693122  0.330687
# gross    0.351464  0.183567  0.745999  0.693122  1.000000  0.257426
# runtime  0.095483  0.412220  0.300576  0.330687  0.257426  1.000000

# %%
correlation_matrix = df.corr()

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Numeric Features")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
# Using factorize - this assigns a random numeric value for each unique categorical value

df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000  0.170201  0.028328  0.965500  0.966118 -0.020185
# rating    0.170201  1.000000 -0.116527  0.179819  0.171415  0.035913
# genre     0.028328 -0.116527  1.000000  0.031663  0.031173 -0.027689
# year      0.965500  0.179819  0.031663  1.000000  0.996492 -0.014673
# released  0.966118  0.171415  0.031173  0.996492  1.000000 -0.019572
# score    -0.020185  0.035913 -0.027689 -0.014673 -0.019572  1.000000
# votes     0.296932  0.097342 -0.010107  0.323565  0.312911 -0.041835
# director  0.725547  0.096534  0.036489  0.747915  0.750923 -0.006680
# writer    0.792039  0.129370  0.033817  0.812533  0.809997 -0.021641
# star      0.695311  0.116100  0.045415  0.719532  0.720234  0.014957
# country   0.098142 -0.004571 -0.003278  0.095117  0.096851  0.016590
# budget    0.288671  0.203730  0.021023  0.318818  0.309298 -0.005642
# gross     0.967952  0.173091  0.031950  0.996385  0.998496 -0.015846
# company   0.535642 -0.025940  0.015133  0.537998  0.546289 -0.008661
# runtime   0.048916  0.031974  0.000440  0.055813  0.049616  0.011806
#
#              votes  director    writer      star   country    budget  \
# name      0.296932  0.725547  0.792039  0.695311  0.098142  0.288671
# rating    0.097342  0.096534  0.129370  0.116100 -0.004571  0.203730
# genre    -0.010107  0.036489  0.033817  0.045415 -0.003278  0.021023
# year      0.323565  0.747915  0.812533  0.719532  0.095117  0.318818
# released  0.312911  0.750923  0.809997  0.720234  0.096851  0.309298
# score    -0.041835 -0.006680 -0.021641  0.014957  0.016590 -0.005642
# votes     1.000000  0.187701  0.224803  0.181782 -0.021506  0.358907
# director  0.187701  1.000000  0.718169  0.636915  0.095321  0.123934
# writer    0.224803  0.718169  1.000000  0.626906  0.098627  0.207884
# star      0.181782  0.636915  0.626906  1.000000  0.098073  0.137738
# country  -0.021506  0.095321  0.098627  0.098073  1.000000  0.016337
# budget    0.358907  0.123934  0.207884  0.137738  0.016337  1.000000
# gross     0.306885  0.751842  0.811505  0.720978  0.094856  0.304969
# company   0.007233  0.483886  0.477786  0.442568  0.153939 -0.053667
# runtime   0.126336 -0.027134  0.022935  0.033149  0.040924  0.134869
#
#              gross   company   runtime
# name      0.967952  0.535642  0.048916
# rating    0.173091 -0.025940  0.031974
# genre     0.031950  0.015133  0.000440
# year      0.996385  0.537998  0.055813
# released  0.998496  0.546289  0.049616
# score    -0.015846 -0.008661  0.011806
# votes     0.306885  0.007233  0.126336
# director  0.751842  0.483886 -0.027134
# writer    0.811505  0.477786  0.022935
# star      0.720978  0.442568  0.033149
# country   0.094856  0.153939  0.040924
# budget    0.304969 -0.053667  0.134869
# gross     1.000000  0.546191  0.047677
# company   0.546191  1.000000 -0.010658
# runtime   0.047677 -0.010658  1.000000

# %%
correlation_matrix = df.apply(lambda x: x.factorize()[0]).corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Movies")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
correlation_mat = df.apply(lambda x: x.factorize()[0]).corr()

corr_pairs = correlation_mat.unstack()

print(corr_pairs)
# Out:
# name     name        1.000000
#          rating      0.170201
#          genre       0.028328
#          year        0.965500
#          released    0.966118
#                        ...
# runtime  country     0.040924
#          budget      0.134869
#          gross       0.047677
#          company    -0.010658
#          runtime     1.000000
# Length: 225, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values(kind="quicksort")

print(sorted_pairs)
# Out:
# rating   genre     -0.116527
# genre    rating    -0.116527
# budget   company   -0.053667
# company  budget    -0.053667
# score    votes     -0.041835
#                       ...
# year     year       1.000000
# genre    genre      1.000000
# rating   rating     1.000000
# company  company    1.000000
# runtime  runtime    1.000000
# Length: 225, dtype: float64

# %%
# We can now take a look at the ones that have a high correlation (> 0.5)

strong_pairs = sorted_pairs[abs(sorted_pairs) > 0.5]

print(strong_pairs)
# Out:
# company  name       0.535642
# name     company    0.535642
# company  year       0.537998
# year     company    0.537998
# gross    company    0.546191
#                       ...
# year     year       1.000000
# genre    genre      1.000000
# rating   rating     1.000000
# company  company    1.000000
# runtime  runtime    1.000000
# Length: 65, dtype: float64

# %%
# Looking at the top 15 compaies by gross revenue

CompanyGrossSum = df.groupby('company')[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values('gross', ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company
# Warner Bros.                 54610959970
# Universal Pictures           51241105418
# Columbia Pictures            42356430218
# Paramount Pictures           40021704691
# Twentieth Century Fox        39542573303
# Walt Disney Pictures         35833650748
# New Line Cinema              19612851164
# Marvel Studios               15065592411
# DreamWorks Animation         11873612858
# Dreamworks Pictures          11593807697
# Touchstone Pictures          10664679494
# Metro-Goldwyn-Mayer (MGM)     8937010092
# Summit Entertainment          8318570396
# Pixar Animation Studios       7886344526
# Fox 2000 Pictures             7243673721
# Name: gross, dtype: int64

# %%
df['Year'] = df['released'].astype(str).str[:4]
df.head()
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 5419                               Bad Boys for Life          R     Action
# 5420                              Sonic the Hedgehog         PG     Action
# 5421                                        Dolittle         PG  Adventure
# 5422                            The Call of the Wild         PG  Adventure
# 5423                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score    votes  \
# 0     1980      June 13, 1980 (United States)    8.4   927000
# 1     1980       July 2, 1980 (United States)    5.8    65000
# 2     1980      June 20, 1980 (United States)    8.7  1200000
# 3     1980       July 2, 1980 (United States)    7.7   221000
# 4     1980      July 25, 1980 (United States)    7.3   108000
# ...    ...                                ...    ...      ...
# 5419  2020   January 17, 2020 (United States)    6.6   140000
# 5420  2020  February 14, 2020 (United States)    6.5   102000
# 5421  2020   January 17, 2020 (United States)    5.6    53000
# 5422  2020  February 21, 2020 (United States)    6.8    42000
# 5423  2020    August 28, 2020 (United States)    6.8     3700
#
#              director                   writer               star  \
# 0     Stanley Kubrick             Stephen King     Jack Nicholson
# 1      Randal Kleiser  Henry De Vere Stacpoole     Brooke Shields
# 2      Irvin Kershner           Leigh Brackett        Mark Hamill
# 3        Jim Abrahams             Jim Abrahams        Robert Hays
# 4        Harold Ramis       Brian Doyle-Murray        Chevy Chase
# ...               ...                      ...                ...
# 5419     Adil El Arbi              Peter Craig         Will Smith
# 5420      Jeff Fowler                Pat Casey       Ben Schwartz
# 5421   Stephen Gaghan           Stephen Gaghan  Robert Downey Jr.
# 5422    Chris Sanders            Michael Green      Harrison Ford
# 5423          Hu Guan                  Hu Guan    Zhi-zhong Huang
#
#              country     budget      gross  \
# 0     United Kingdom   19000000   46998772
# 1      United States    4500000   58853106
# 2      United States   18000000  538375067
# 3      United States    3500000   83453539
# 4      United States    6000000   39846344
# ...              ...        ...        ...
# 5419   United States   90000000  426505244
# 5420   United States   85000000  319715683
# 5421   United States  175000000  245487753
# 5422          Canada  135000000  111105497
# 5423           China   80000000  461421559
#
#                                   company  runtime  Year
# 0                            Warner Bros.    146.0  June
# 1                       Columbia Pictures    104.0  July
# 2                               Lucasfilm    124.0  June
# 3                      Paramount Pictures     88.0  July
# 4                          Orion Pictures     98.0  July
# ...                                   ...      ...   ...
# 5419                    Columbia Pictures    124.0  Janu
# 5420                   Paramount Pictures     99.0  Febr
# 5421                   Universal Pictures    101.0  Janu
# 5422                 20th Century Studios    100.0  Febr
# 5423  Beijing Diqi Yinxiang Entertainment    149.0  Augu
#
# [5424 rows x 16 columns]

# %%
df['Year'] = df['released'].astype(str).str[:4]
df.head()
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 5419                               Bad Boys for Life          R     Action
# 5420                              Sonic the Hedgehog         PG     Action
# 5421                                        Dolittle         PG  Adventure
# 5422                            The Call of the Wild         PG  Adventure
# 5423                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score    votes  \
# 0     1980      June 13, 1980 (United States)    8.4   927000
# 1     1980       July 2, 1980 (United States)    5.8    65000
# 2     1980      June 20, 1980 (United States)    8.7  1200000
# 3     1980       July 2, 1980 (United States)    7.7   221000
# 4     1980      July 25, 1980 (United States)    7.3   108000
# ...    ...                                ...    ...      ...
# 5419  2020   January 17, 2020 (United States)    6.6   140000
# 5420  2020  February 14, 2020 (United States)    6.5   102000
# 5421  2020   January 17, 2020 (United States)    5.6    53000
# 5422  2020  February 21, 2020 (United States)    6.8    42000
# 5423  2020    August 28, 2020 (United States)    6.8     3700
#
#              director                   writer               star  \
# 0     Stanley Kubrick             Stephen King     Jack Nicholson
# 1      Randal Kleiser  Henry De Vere Stacpoole     Brooke Shields
# 2      Irvin Kershner           Leigh Brackett        Mark Hamill
# 3        Jim Abrahams             Jim Abrahams        Robert Hays
# 4        Harold Ramis       Brian Doyle-Murray        Chevy Chase
# ...               ...                      ...                ...
# 5419     Adil El Arbi              Peter Craig         Will Smith
# 5420      Jeff Fowler                Pat Casey       Ben Schwartz
# 5421   Stephen Gaghan           Stephen Gaghan  Robert Downey Jr.
# 5422    Chris Sanders            Michael Green      Harrison Ford
# 5423          Hu Guan                  Hu Guan    Zhi-zhong Huang
#
#              country     budget      gross  \
# 0     United Kingdom   19000000   46998772
# 1      United States    4500000   58853106
# 2      United States   18000000  538375067
# 3      United States    3500000   83453539
# 4      United States    6000000   39846344
# ...              ...        ...        ...
# 5419   United States   90000000  426505244
# 5420   United States   85000000  319715683
# 5421   United States  175000000  245487753
# 5422          Canada  135000000  111105497
# 5423           China   80000000  461421559
#
#                                   company  runtime  Year
# 0                            Warner Bros.    146.0  June
# 1                       Columbia Pictures    104.0  July
# 2                               Lucasfilm    124.0  June
# 3                      Paramount Pictures     88.0  July
# 4                          Orion Pictures     98.0  July
# ...                                   ...      ...   ...
# 5419                    Columbia Pictures    124.0  Janu
# 5420                   Paramount Pictures     99.0  Febr
# 5421                   Universal Pictures    101.0  Janu
# 5422                 20th Century Studios    100.0  Febr
# 5423  Beijing Diqi Yinxiang Entertainment    149.0  Augu
#
# [5424 rows x 16 columns]

# %%
CompanyGrossSum = df.groupby(['company', 'year'])[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values(['gross','company','year'], ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company                year
# Walt Disney Pictures   2019    5773131804
# Marvel Studios         2018    4018631866
# Universal Pictures     2015    3834354888
# Twentieth Century Fox  2009    3793491246
# Walt Disney Pictures   2017    3789382071
# Paramount Pictures     2011    3565705182
# Warner Bros.           2011    3223799224
# Walt Disney Pictures   2010    3104474158
# Paramount Pictures     2014    3071298586
# Columbia Pictures      2006    2934631933
#                        2019    2932757449
# Marvel Studios         2019    2797501328
# Warner Bros.           2018    2774168962
# Columbia Pictures      2011    2738363306
# Warner Bros.           2005    2688767210
# Name: gross, dtype: int64

# %%
CompanyGrossSum = df.groupby(['company', 'year'])[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values(['gross','company','year'], ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company                year
# Walt Disney Pictures   2019    5773131804
# Marvel Studios         2018    4018631866
# Universal Pictures     2015    3834354888
# Twentieth Century Fox  2009    3793491246
# Walt Disney Pictures   2017    3789382071
# Paramount Pictures     2011    3565705182
# Warner Bros.           2011    3223799224
# Walt Disney Pictures   2010    3104474158
# Paramount Pictures     2014    3071298586
# Columbia Pictures      2006    2934631933
#                        2019    2932757449
# Marvel Studios         2019    2797501328
# Warner Bros.           2018    2774168962
# Columbia Pictures      2011    2738363306
# Warner Bros.           2005    2688767210
# Name: gross, dtype: int64

# %%
plt.scatter(x=df['budget'], y=df['gross'], alpha=0.5)
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')
plt.show()

# %%
df.head()
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 5419                               Bad Boys for Life          R     Action
# 5420                              Sonic the Hedgehog         PG     Action
# 5421                                        Dolittle         PG  Adventure
# 5422                            The Call of the Wild         PG  Adventure
# 5423                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score    votes  \
# 0     1980      June 13, 1980 (United States)    8.4   927000
# 1     1980       July 2, 1980 (United States)    5.8    65000
# 2     1980      June 20, 1980 (United States)    8.7  1200000
# 3     1980       July 2, 1980 (United States)    7.7   221000
# 4     1980      July 25, 1980 (United States)    7.3   108000
# ...    ...                                ...    ...      ...
# 5419  2020   January 17, 2020 (United States)    6.6   140000
# 5420  2020  February 14, 2020 (United States)    6.5   102000
# 5421  2020   January 17, 2020 (United States)    5.6    53000
# 5422  2020  February 21, 2020 (United States)    6.8    42000
# 5423  2020    August 28, 2020 (United States)    6.8     3700
#
#              director                   writer               star  \
# 0     Stanley Kubrick             Stephen King     Jack Nicholson
# 1      Randal Kleiser  Henry De Vere Stacpoole     Brooke Shields
# 2      Irvin Kershner           Leigh Brackett        Mark Hamill
# 3        Jim Abrahams             Jim Abrahams        Robert Hays
# 4        Harold Ramis       Brian Doyle-Murray        Chevy Chase
# ...               ...                      ...                ...
# 5419     Adil El Arbi              Peter Craig         Will Smith
# 5420      Jeff Fowler                Pat Casey       Ben Schwartz
# 5421   Stephen Gaghan           Stephen Gaghan  Robert Downey Jr.
# 5422    Chris Sanders            Michael Green      Harrison Ford
# 5423          Hu Guan                  Hu Guan    Zhi-zhong Huang
#
#              country     budget      gross  \
# 0     United Kingdom   19000000   46998772
# 1      United States    4500000   58853106
# 2      United States   18000000  538375067
# 3      United States    3500000   83453539
# 4      United States    6000000   39846344
# ...              ...        ...        ...
# 5419   United States   90000000  426505244
# 5420   United States   85000000  319715683
# 5421   United States  175000000  245487753
# 5422          Canada  135000000  111105497
# 5423           China   80000000  461421559
#
#                                   company  runtime  Year
# 0                            Warner Bros.    146.0  June
# 1                       Columbia Pictures    104.0  July
# 2                               Lucasfilm    124.0  June
# 3                      Paramount Pictures     88.0  July
# 4                          Orion Pictures     98.0  July
# ...                                   ...      ...   ...
# 5419                    Columbia Pictures    124.0  Janu
# 5420                   Paramount Pictures     99.0  Febr
# 5421                   Universal Pictures    101.0  Janu
# 5422                 20th Century Studios    100.0  Febr
# 5423  Beijing Diqi Yinxiang Entertainment    149.0  Augu
#
# [5424 rows x 16 columns]

# %%
df_numerized = df


for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name]= df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 0     4695       6      6  1980      1304    8.4   927000      1797    2834
# 1     3932       6      1  1980      1127    5.8    65000      1579    1159
# 2     3643       4      0  1980      1359    8.7  1200000       757    1819
# 3      204       4      4  1980      1127    7.7   221000       889    1414
# 4      732       6      4  1980      1170    7.3   108000       719     352
# ...    ...     ...    ...   ...       ...    ...      ...       ...     ...
# 5419   415       6      0  2020       904    6.6   140000        16    2391
# 5420  3558       4      0  2020       713    6.5   102000       852    2310
# 5421  1153       4      1  2020       904    5.6    53000      1811    2829
# 5422  3981       4      1  2020       758    6.8    42000       294    2092
# 5423  4093       3      0  2020       370    6.8     3700       746    1185
#
#       star  country     budget      gross  company  runtime  Year
# 0      699       46   19000000   46998772     1426    146.0    11
# 1      214       47    4500000   58853106      452    104.0    10
# 2     1157       47   18000000  538375067      945    124.0    11
# 3     1474       47    3500000   83453539     1108     88.0    10
# 4      271       47    6000000   39846344     1083     98.0    10
# ...    ...      ...        ...        ...      ...      ...   ...
# 5419  1812       47   90000000  426505244      452    124.0     9
# 5420   147       47   85000000  319715683     1108     99.0     8
# 5421  1470       47  175000000  245487753     1397    101.0     9
# 5422   640        6  135000000  111105497       12    100.0     8
# 5423  1839        8   80000000  461421559      228    149.0     6
#
# [5424 rows x 16 columns]

# %%
df_numerized.corr(method='pearson')
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.029271  0.010838  0.025441 -0.005783  0.014521
# rating   -0.029271  1.000000  0.147569  0.020085  0.018011  0.066335
# genre     0.010838  0.147569  1.000000 -0.073532  0.021952  0.035126
# year      0.025441  0.020085 -0.073532  1.000000 -0.002033  0.056506
# released -0.005783  0.018011  0.021952 -0.002033  1.000000  0.046131
# score     0.014521  0.066335  0.035126  0.056506  0.046131  1.000000
# votes     0.012585  0.006321 -0.135954  0.206161  0.028810  0.474349
# director  0.015320  0.014381 -0.008507 -0.038676  0.002499  0.005294
# writer    0.013143 -0.002966  0.016969 -0.025486  0.008480  0.012896
# star     -0.006788  0.009693  0.003026 -0.031559  0.015881  0.007683
# country  -0.025467  0.008061 -0.009185 -0.066833 -0.017225 -0.043207
# budget    0.023336 -0.203531 -0.368521  0.327961  0.019835  0.072155
# gross     0.005613 -0.181590 -0.244034  0.274395  0.008492  0.222709
# company   0.021592 -0.091306 -0.071608 -0.013187 -0.002539  0.021241
# runtime   0.010949  0.140886 -0.059367  0.075173  0.009172  0.414145
# Year     -0.007006  0.015479  0.021115 -0.005344  0.996184  0.045405
#
#              votes  director    writer      star   country    budget  \
# name      0.012585  0.015320  0.013143 -0.006788 -0.025467  0.023336
# rating    0.006321  0.014381 -0.002966  0.009693  0.008061 -0.203531
# genre    -0.135954 -0.008507  0.016969  0.003026 -0.009185 -0.368521
# year      0.206161 -0.038676 -0.025486 -0.031559 -0.066833  0.327961
# released  0.028810  0.002499  0.008480  0.015881 -0.017225  0.019835
# score     0.474349  0.005294  0.012896  0.007683 -0.043207  0.072155
# votes     1.000000 -0.010499 -0.005288 -0.017377  0.041443  0.439757
# director -0.010499  1.000000  0.261595  0.036372  0.011209 -0.009814
# writer   -0.005288  0.261595  1.000000  0.018941  0.022496 -0.039307
# star     -0.017377  0.036372  0.018941  1.000000 -0.010125 -0.021159
# country   0.041443  0.011209  0.022496 -0.010125  1.000000  0.052878
# budget    0.439757 -0.009814 -0.039307 -0.021159  0.052878  1.000000
# gross     0.614808 -0.029664 -0.035842  0.000218  0.059982  0.740263
# company   0.118850 -0.008712 -0.003287  0.014958  0.048258  0.170676
# runtime   0.352331  0.017437 -0.017340  0.010312 -0.034514  0.318718
# Year      0.027522  0.003676  0.008004  0.015109 -0.016960  0.018223
#
#              gross   company   runtime      Year
# name      0.005613  0.021592  0.010949 -0.007006
# rating   -0.181590 -0.091306  0.140886  0.015479
# genre    -0.244034 -0.071608 -0.059367  0.021115
# year      0.274395 -0.013187  0.075173 -0.005344
# released  0.008492 -0.002539  0.009172  0.996184
# score     0.222709  0.021241  0.414145  0.045405
# votes     0.614808  0.118850  0.352331  0.027522
# director -0.029664 -0.008712  0.017437  0.003676
# writer   -0.035842 -0.003287 -0.017340  0.008004
# star      0.000218  0.014958  0.010312  0.015109
# country   0.059982  0.048258 -0.034514 -0.016960
# budget    0.740263  0.170676  0.318718  0.018223
# gross     1.000000  0.149843  0.275830  0.006873
# company   0.149843  1.000000  0.037797 -0.002464
# runtime   0.275830  0.037797  1.000000  0.007367
# Year      0.006873 -0.002464  0.007367  1.000000

# %%
correlation_matrix = df_numerized.corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Movies")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
df_numerized.corr()
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.029271  0.010838  0.025441 -0.005783  0.014521
# rating   -0.029271  1.000000  0.147569  0.020085  0.018011  0.066335
# genre     0.010838  0.147569  1.000000 -0.073532  0.021952  0.035126
# year      0.025441  0.020085 -0.073532  1.000000 -0.002033  0.056506
# released -0.005783  0.018011  0.021952 -0.002033  1.000000  0.046131
# score     0.014521  0.066335  0.035126  0.056506  0.046131  1.000000
# votes     0.012585  0.006321 -0.135954  0.206161  0.028810  0.474349
# director  0.015320  0.014381 -0.008507 -0.038676  0.002499  0.005294
# writer    0.013143 -0.002966  0.016969 -0.025486  0.008480  0.012896
# star     -0.006788  0.009693  0.003026 -0.031559  0.015881  0.007683
# country  -0.025467  0.008061 -0.009185 -0.066833 -0.017225 -0.043207
# budget    0.023336 -0.203531 -0.368521  0.327961  0.019835  0.072155
# gross     0.005613 -0.181590 -0.244034  0.274395  0.008492  0.222709
# company   0.021592 -0.091306 -0.071608 -0.013187 -0.002539  0.021241
# runtime   0.010949  0.140886 -0.059367  0.075173  0.009172  0.414145
# Year     -0.007006  0.015479  0.021115 -0.005344  0.996184  0.045405
#
#              votes  director    writer      star   country    budget  \
# name      0.012585  0.015320  0.013143 -0.006788 -0.025467  0.023336
# rating    0.006321  0.014381 -0.002966  0.009693  0.008061 -0.203531
# genre    -0.135954 -0.008507  0.016969  0.003026 -0.009185 -0.368521
# year      0.206161 -0.038676 -0.025486 -0.031559 -0.066833  0.327961
# released  0.028810  0.002499  0.008480  0.015881 -0.017225  0.019835
# score     0.474349  0.005294  0.012896  0.007683 -0.043207  0.072155
# votes     1.000000 -0.010499 -0.005288 -0.017377  0.041443  0.439757
# director -0.010499  1.000000  0.261595  0.036372  0.011209 -0.009814
# writer   -0.005288  0.261595  1.000000  0.018941  0.022496 -0.039307
# star     -0.017377  0.036372  0.018941  1.000000 -0.010125 -0.021159
# country   0.041443  0.011209  0.022496 -0.010125  1.000000  0.052878
# budget    0.439757 -0.009814 -0.039307 -0.021159  0.052878  1.000000
# gross     0.614808 -0.029664 -0.035842  0.000218  0.059982  0.740263
# company   0.118850 -0.008712 -0.003287  0.014958  0.048258  0.170676
# runtime   0.352331  0.017437 -0.017340  0.010312 -0.034514  0.318718
# Year      0.027522  0.003676  0.008004  0.015109 -0.016960  0.018223
#
#              gross   company   runtime      Year
# name      0.005613  0.021592  0.010949 -0.007006
# rating   -0.181590 -0.091306  0.140886  0.015479
# genre    -0.244034 -0.071608 -0.059367  0.021115
# year      0.274395 -0.013187  0.075173 -0.005344
# released  0.008492 -0.002539  0.009172  0.996184
# score     0.222709  0.021241  0.414145  0.045405
# votes     0.614808  0.118850  0.352331  0.027522
# director -0.029664 -0.008712  0.017437  0.003676
# writer   -0.035842 -0.003287 -0.017340  0.008004
# star      0.000218  0.014958  0.010312  0.015109
# country   0.059982  0.048258 -0.034514 -0.016960
# budget    0.740263  0.170676  0.318718  0.018223
# gross     1.000000  0.149843  0.275830  0.006873
# company   0.149843  1.000000  0.037797 -0.002464
# runtime   0.275830  0.037797  1.000000  0.007367
# Year      0.006873 -0.002464  0.007367  1.000000

# %%
correlation_mat = df_numerized.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# name  name        1.000000
#       rating     -0.029271
#       genre       0.010838
#       year        0.025441
#       released   -0.005783
#                     ...
# Year  budget      0.018223
#       gross       0.006873
#       company    -0.002464
#       runtime     0.007367
#       Year        1.000000
# Length: 256, dtype: float64
